# %%
# !pip install rouge
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.llms import CTransformers
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge

DB_FAISS_PATH = 'new_db_faiss'

# Define custom prompt template
custom_prompt_template = """Use the following pieces of information to answer the user's question.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

Context: {context}
Question: {question}

Only return the helpful answer below and nothing else.
Helpful answer:
"""

def set_custom_prompt():
    prompt = PromptTemplate(template=custom_prompt_template, input_variables=['context', 'question'])
    return prompt
# Update QA Bot to handle single file loading
def qa_bot():
    # Load document directly with PyPDFLoader
    loader = PyPDFLoader(DATA_PATH)
    documents = loader.load()

    # Split documents
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=50)
    texts = text_splitter.split_documents(documents)

    # Embed chunks
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2", model_kwargs={'device': 'cpu'})
    db = FAISS.from_documents(texts, embeddings)
    db.save_local(DB_FAISS_PATH)  # Save only if creating it initially

    # Setup QA with prompt
    llm = load_llm()
    qa_prompt = set_custom_prompt()
    qa = retrieval_qa_chain(llm, qa_prompt, db)

    return qa

def retrieval_qa_chain(llm, prompt, db):
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type='stuff',
        retriever=db.as_retriever(search_kwargs={'k': 2}),
        return_source_documents=True,
        chain_type_kwargs={'prompt': prompt}
    )
    return qa_chain
# Load language model
def load_llm():
    llm = CTransformers(
        model="TheBloke/Llama-2-7B-Chat-GGML",
        model_type="llama",
        max_new_tokens=512,
        temperature=0.3
    )
    return llm

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.llms import CTransformers
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge
DB_FAISS_PATH = 'new_db_faiss'
DATA_PATH=''
# Define custom prompt template
custom_prompt_template = """Use the following pieces of information to answer the user's question.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

Context: {context}
Question: {question}

Only return the helpful answer below and nothing else.
Helpful answer:
"""

def set_custom_prompt():
    prompt = PromptTemplate(template=custom_prompt_template, input_variables=['context', 'question'])
    return prompt
# Update QA Bot to handle single file loading
def qa_bot():
    # Load document directly with PyPDFLoader
    loader = PyPDFLoader(DATA_PATH)
    documents = loader.load()

    # Split documents
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=50)
    texts = text_splitter.split_documents(documents)

    # Embed chunks
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2", model_kwargs={'device': 'gpu'})
    db = FAISS.from_documents(texts, embeddings)
    db.save_local(DB_FAISS_PATH)  # Save only if creating it initially

    # Setup QA with prompt
    llm = load_llm()
    qa_prompt = set_custom_prompt()
    qa = retrieval_qa_chain(llm, qa_prompt, db)

    return qa

def retrieval_qa_chain(llm, prompt, db):
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type='stuff',
        retriever=db.as_retriever(search_kwargs={'k': 2}),
        return_source_documents=True,
        chain_type_kwargs={'prompt': prompt}
    )
    return qa_chain
# Load language model
def load_llm():
    llm = CTransformers(
        model="TheBloke/Llama-2-7B-Chat-GGML",
        model_type="llama",
        max_new_tokens=512,
        temperature=0.3
    )
    return llm
# Define BLEU and ROUGE evaluation functions
smooth = SmoothingFunction().method4
rouge = Rouge()

def evaluate_response(generated, reference):
    bleu_score = sentence_bleu([reference.split()], generated.split(), smoothing_function=smooth)
    rouge_score = rouge.get_scores(generated, reference, avg=True)
    return bleu_score, rouge_score

# %%
# # QA and evaluation pipeline
# def final_result(query, reference):
#     qa_result = qa_bot()
#     response = qa_result({'query': query})  # Run the query
#     generated_answer = response['result']
    
#     # Evaluate response
#     bleu_score, rouge_score = evaluate_response(generated_answer, reference)
#     return generated_answer, bleu_score, rouge_score

# Run `qa_bot()` once before entering the main loop
qa_instance = qa_bot()  # Initialize once

# Update `final_result` to accept `qa_instance` as an argument
# QA and evaluation pipeline
def final_result(query, reference):
    qa_result = qa_bot()
    response = qa_result({'query': query})  # Run the query
    generated_answer = response['result']
    
    # Evaluate response
    bleu_score, rouge_score = evaluate_response(generated_answer, reference)
    return generated_answer, bleu_score, rouge_score

# Colab user interaction loop
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 12
#       1 # # QA and evaluation pipeline
#       2 # def final_result(query, reference):
#       3 #     qa_result = qa_bot()
#    (...)
#      10
#      11 # Run `qa_bot()` once before entering the main loop
# ---> 12 qa_instance = qa_bot()  # Initialize once
#      14 # Update `final_result` to accept `qa_instance` as an argument
#      15 # QA and evaluation pipeline
#      16 def final_result(query, reference):
#
# Cell In[4], line 29, in qa_bot()
#      27 def qa_bot():
#      28     # Load document directly with PyPDFLoader
# ---> 29     loader = PyPDFLoader(DATA_PATH)
#      30     documents = loader.load()
#      32     # Split documents
#
# File c:\Users\Anshul Shinde\.conda\envs\clg\lib\site-packages\langchain_community\document_loaders\pdf.py:241, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images, extraction_mode, extraction_kwargs)
#     237 except ImportError:
#     238     raise ImportError(
#     239         "pypdf package not found, please install it with `pip install pypdf`"
#     240     )
# --> 241 super().__init__(file_path, headers=headers)
#     242 self.parser = PyPDFParser(
#     243     password=password,
#     244     extract_images=extract_images,
#     245     extraction_mode=extraction_mode,
#     246     extraction_kwargs=extraction_kwargs,
#     247 )
#
# File c:\Users\Anshul Shinde\.conda\envs\clg\lib\site-packages\langchain_community\document_loaders\pdf.py:117, in BasePDFLoader.__init__(self, file_path, headers)
#     115         self.file_path = str(temp_pdf)
#     116 elif not os.path.isfile(self.file_path):
# --> 117     raise ValueError("File path %s is not a valid file or url" % self.file_path)
#
# ValueError: File path  is not a valid file or url

# %%
# Colab user interaction
print("Welcome to Medical Bot! Enter your query below.")
while True:
    user_query = input("Your Question: ")
    if user_query.lower() == "exit":
        print("Goodbye!")
        break
    
    # Example reference answer for evaluation
    # Replace this with actual reference answers for each query if available
    reference_answer = "Acne is a common skin disease characterized by pimples on the face, chest, and back."
    
    # Get answer and evaluation metrics
    answer, bleu, rouge = final_result(user_query, reference_answer)
    
    # Print results
    print("Answer:", answer)
    print("BLEU Score:", bleu)
    print("ROUGE Score:", rouge)
# Out:
# Welcome to Medical Bot! Enter your query below.

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.llms import CTransformers
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# Set file path for local use
DATA_PATH = "NLP_FINAL.pdf"
DB_FAISS_PATH = "db_faiss"

# Custom prompt template
custom_prompt_template = """Use the following pieces of information to answer the user's question.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

Context: {context}
Question: {question}

Only return the helpful answer below and nothing else.
Helpful answer:
"""

def set_custom_prompt():
    prompt = PromptTemplate(template=custom_prompt_template, input_variables=['context', 'question'])
    return prompt

# Load language model
def load_llm():
    llm = CTransformers(
        model="TheBloke/Llama-2-7B-Chat-GGML",
        model_type="llama",
        max_new_tokens=512,
        temperature=0.3
    )
    return llm

# Update QA Bot to handle single file loading
def qa_bot():
    loader = PyPDFLoader(DATA_PATH)
    documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    texts = text_splitter.split_documents(documents)

    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2", model_kwargs={'device': 'cpu'})
    db = FAISS.from_documents(texts, embeddings)
    db.save_local(DB_FAISS_PATH)  # Save only if creating it initially

    llm = load_llm()
    qa_prompt = set_custom_prompt()
    qa = retrieval_qa_chain(llm, qa_prompt, db)

    return qa

def retrieval_qa_chain(llm, prompt, db):
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type='stuff',
        retriever=db.as_retriever(search_kwargs={'k': 2}),
        return_source_documents=True,
        chain_type_kwargs={'prompt': prompt}
    )
    return qa_chain

# BLEU and ROUGE evaluation functions
smooth = SmoothingFunction().method4
rouge_instance = Rouge()

def evaluate_response(generated, reference):
    bleu_score = sentence_bleu([reference.split()], generated.split(), smoothing_function=smooth)
    rouge_score = rouge_instance.get_scores(generated, reference, avg=True)
    return bleu_score, rouge_score['rouge-l']['f']

# Initialize a dictionary with reference answers for different questions
reference_answers = {
    "What causes acne?": "Acne is caused by clogged hair follicles and excess oil production.",
    "What are the symptoms of diabetes?": "The symptoms of diabetes include frequent urination, increased thirst, and unexplained weight loss.",
    "What is hypertension?": "Hypertension, or high blood pressure, is a condition where the force of blood against the artery walls is way too much .",
    # Add more question-reference pairs as needed
}

# QA and evaluation pipeline
def final_result(query, qa_instance):
    # Retrieve the corresponding reference answer for each query
    reference_answer = reference_answers.get(query, "No specific reference answer available.")
    
    # Run the query through the QA system
    response = qa_instance.invoke({'query': query})
    generated_answer = response['result']
    
    # Evaluate the response
    bleu_score, rouge_score = evaluate_response(generated_answer, reference_answer)
    return generated_answer, bleu_score, rouge_score

# Initialize QA bot once to avoid reloading
qa_instance = qa_bot()

# Lists to store BLEU and ROUGE scores
bleu_scores = []
rouge_scores = []
queries = []

# Colab user interaction
print("Welcome to Medical Bot! Enter your query below.")
while True:
    user_query = input("Your Question: ")
    if user_query.lower() == "exit":
        print("Goodbye!")
        break

    # Get answer and evaluation metrics
    answer, bleu, rouge = final_result(user_query, qa_instance)

    # Append scores for plotting
    bleu_scores.append(bleu)
    rouge_scores.append(rouge)
    queries.append(user_query)

    # Print results
    print("Answer:", answer)
    print("BLEU Score:", bleu)
    print("ROUGE Score:", rouge)

# Plot the BLEU and ROUGE scores after exit
plt.figure(figsize=(12, 6))

# Plot BLEU Scores
plt.subplot(1, 2, 1)
plt.plot(range(len(bleu_scores)), bleu_scores, label='BLEU Score', marker='o')
plt.xlabel("Query Number")
plt.ylabel("BLEU Score")
plt.title("BLEU Scores Over Queries")
plt.legend()

# Plot ROUGE Scores
plt.subplot(1, 2, 2)
plt.plot(range(len(rouge_scores)), rouge_scores, label='ROUGE-L Score', marker='o', color='orange')
plt.xlabel("Query Number")
plt.ylabel("ROUGE-L Score")
plt.title("ROUGE-L Scores Over Queries")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Ignoring wrong pointing object 57 0 (offset 0)
# Ignoring wrong pointing object 82 0 (offset 0)
# Ignoring wrong pointing object 84 0 (offset 0)
# Ignoring wrong pointing object 198 0 (offset 0)
# Ignoring wrong pointing object 301 0 (offset 0)
# Ignoring wrong pointing object 303 0 (offset 0)
# Ignoring wrong pointing object 305 0 (offset 0)
# Ignoring wrong pointing object 307 0 (offset 0)
# Ignoring wrong pointing object 309 0 (offset 0)
# Ignoring wrong pointing object 352 0 (offset 0)
# Ignoring wrong pointing object 390 0 (offset 0)
# Ignoring wrong pointing object 392 0 (offset 0)
# Ignoring wrong pointing object 404 0 (offset 0)
# Ignoring wrong pointing object 425 0 (offset 0)
# Ignoring wrong pointing object 452 0 (offset 0)
# Ignoring wrong pointing object 666 0 (offset 0)
# Ignoring wrong pointing object 692 0 (offset 0)
# Ignoring wrong pointing object 721 0 (offset 0)
# Ignoring wrong pointing object 723 0 (offset 0)
# Ignoring wrong pointing object 778 0 (offset 0)
# Ignoring wrong pointing object 854 0 (offset 0)
# Ignoring wrong pointing object 859 0 (offset 0)
# Ignoring wrong pointing object 861 0 (offset 0)
# Ignoring wrong pointing object 881 0 (offset 0)
# Ignoring wrong pointing object 899 0 (offset 0)
# Ignoring wrong pointing object 915 0 (offset 0)
# Ignoring wrong pointing object 931 0 (offset 0)
# Ignoring wrong pointing object 1030 0 (offset 0)
# Ignoring wrong pointing object 1035 0 (offset 0)
# Ignoring wrong pointing object 1037 0 (offset 0)
# Ignoring wrong pointing object 1124 0 (offset 0)
# Ignoring wrong pointing object 1133 0 (offset 0)
# Ignoring wrong pointing object 1143 0 (offset 0)
# Ignoring wrong pointing object 1174 0 (offset 0)
# Ignoring wrong pointing object 1190 0 (offset 0)
# Ignoring wrong pointing object 1196 0 (offset 0)
# Ignoring wrong pointing object 1235 0 (offset 0)
# Ignoring wrong pointing object 1284 0 (offset 0)
# Ignoring wrong pointing object 1325 0 (offset 0)
# Ignoring wrong pointing object 1354 0 (offset 0)
# Ignoring wrong pointing object 1386 0 (offset 0)
# Ignoring wrong pointing object 1470 0 (offset 0)
# Ignoring wrong pointing object 1502 0 (offset 0)
# Ignoring wrong pointing object 1509 0 (offset 0)
# Ignoring wrong pointing object 1557 0 (offset 0)
# Ignoring wrong pointing object 1581 0 (offset 0)
# Ignoring wrong pointing object 1603 0 (offset 0)
# Ignoring wrong pointing object 1612 0 (offset 0)
# Ignoring wrong pointing object 1615 0 (offset 0)
# Ignoring wrong pointing object 1617 0 (offset 0)
# Ignoring wrong pointing object 1677 0 (offset 0)
# Ignoring wrong pointing object 1703 0 (offset 0)
# Ignoring wrong pointing object 1734 0 (offset 0)
# Ignoring wrong pointing object 1749 0 (offset 0)
# Ignoring wrong pointing object 1782 0 (offset 0)
# Ignoring wrong pointing object 1803 0 (offset 0)
# Ignoring wrong pointing object 1847 0 (offset 0)
# Ignoring wrong pointing object 1907 0 (offset 0)
# Ignoring wrong pointing object 1909 0 (offset 0)
# Ignoring wrong pointing object 1918 0 (offset 0)
# Ignoring wrong pointing object 1967 0 (offset 0)
# Ignoring wrong pointing object 1975 0 (offset 0)
# Ignoring wrong pointing object 1989 0 (offset 0)
# Ignoring wrong pointing object 2056 0 (offset 0)
# Ignoring wrong pointing object 2058 0 (offset 0)
# Ignoring wrong pointing object 2119 0 (offset 0)
# Ignoring wrong pointing object 2147 0 (offset 0)
# Ignoring wrong pointing object 2155 0 (offset 0)
# Ignoring wrong pointing object 2197 0 (offset 0)
# Ignoring wrong pointing object 2219 0 (offset 0)
# Ignoring wrong pointing object 2256 0 (offset 0)
# Ignoring wrong pointing object 2259 0 (offset 0)
# Ignoring wrong pointing object 2261 0 (offset 0)
# Ignoring wrong pointing object 2267 0 (offset 0)
# Ignoring wrong pointing object 2274 0 (offset 0)
# Ignoring wrong pointing object 2342 0 (offset 0)
# Ignoring wrong pointing object 2390 0 (offset 0)
# Ignoring wrong pointing object 2395 0 (offset 0)
# Ignoring wrong pointing object 2428 0 (offset 0)
# Ignoring wrong pointing object 2464 0 (offset 0)
# Ignoring wrong pointing object 2472 0 (offset 0)
# Ignoring wrong pointing object 2495 0 (offset 0)
# Ignoring wrong pointing object 2553 0 (offset 0)
# Ignoring wrong pointing object 2558 0 (offset 0)
# Ignoring wrong pointing object 2642 0 (offset 0)
# Ignoring wrong pointing object 2705 0 (offset 0)
# Ignoring wrong pointing object 2713 0 (offset 0)
# Ignoring wrong pointing object 2724 0 (offset 0)
# Ignoring wrong pointing object 2735 0 (offset 0)
# Ignoring wrong pointing object 2761 0 (offset 0)
# Ignoring wrong pointing object 2763 0 (offset 0)
# Ignoring wrong pointing object 2784 0 (offset 0)
# Ignoring wrong pointing object 2802 0 (offset 0)
# Ignoring wrong pointing object 2807 0 (offset 0)
# Ignoring wrong pointing object 2815 0 (offset 0)
# Ignoring wrong pointing object 2832 0 (offset 0)
# Ignoring wrong pointing object 2860 0 (offset 0)
# Ignoring wrong pointing object 2862 0 (offset 0)
# Ignoring wrong pointing object 2878 0 (offset 0)
# Ignoring wrong pointing object 2884 0 (offset 0)
# Ignoring wrong pointing object 2907 0 (offset 0)
# Ignoring wrong pointing object 2971 0 (offset 0)
# Ignoring wrong pointing object 2987 0 (offset 0)
# Ignoring wrong pointing object 3039 0 (offset 0)
# Ignoring wrong pointing object 3053 0 (offset 0)
# Ignoring wrong pointing object 3095 0 (offset 0)
# Ignoring wrong pointing object 3119 0 (offset 0)
# Ignoring wrong pointing object 3130 0 (offset 0)
# Ignoring wrong pointing object 3132 0 (offset 0)
# Ignoring wrong pointing object 3141 0 (offset 0)
# Ignoring wrong pointing object 3156 0 (offset 0)
# Ignoring wrong pointing object 3199 0 (offset 0)
# Ignoring wrong pointing object 3216 0 (offset 0)
# Ignoring wrong pointing object 3228 0 (offset 0)
# Ignoring wrong pointing object 3246 0 (offset 0)
# Ignoring wrong pointing object 3251 0 (offset 0)
# Ignoring wrong pointing object 3323 0 (offset 0)
# Ignoring wrong pointing object 3354 0 (offset 0)
# Ignoring wrong pointing object 3390 0 (offset 0)
# Ignoring wrong pointing object 3435 0 (offset 0)
# Ignoring wrong pointing object 3447 0 (offset 0)
# Ignoring wrong pointing object 3498 0 (offset 0)
# Ignoring wrong pointing object 3509 0 (offset 0)
# Ignoring wrong pointing object 3525 0 (offset 0)
# Ignoring wrong pointing object 3557 0 (offset 0)
# Ignoring wrong pointing object 3608 0 (offset 0)
# Ignoring wrong pointing object 3659 0 (offset 0)
# Ignoring wrong pointing object 3705 0 (offset 0)
# Ignoring wrong pointing object 3737 0 (offset 0)
# Ignoring wrong pointing object 3756 0 (offset 0)
# Ignoring wrong pointing object 3787 0 (offset 0)
# Ignoring wrong pointing object 3831 0 (offset 0)
# Ignoring wrong pointing object 3854 0 (offset 0)
# Ignoring wrong pointing object 3899 0 (offset 0)
# Ignoring wrong pointing object 3904 0 (offset 0)
# Ignoring wrong pointing object 3944 0 (offset 0)
# Ignoring wrong pointing object 3967 0 (offset 0)
# Ignoring wrong pointing object 3989 0 (offset 0)
# Ignoring wrong pointing object 3991 0 (offset 0)
# Ignoring wrong pointing object 4066 0 (offset 0)
# Ignoring wrong pointing object 4072 0 (offset 0)
# Ignoring wrong pointing object 4156 0 (offset 0)
# Ignoring wrong pointing object 4159 0 (offset 0)
# Ignoring wrong pointing object 4169 0 (offset 0)
# Ignoring wrong pointing object 4231 0 (offset 0)
# Ignoring wrong pointing object 4252 0 (offset 0)
# Ignoring wrong pointing object 4312 0 (offset 0)
# Ignoring wrong pointing object 4439 0 (offset 0)
# Ignoring wrong pointing object 4814 0 (offset 0)
# Ignoring wrong pointing object 19080 0 (offset 0)
# Ignoring wrong pointing object 19136 0 (offset 0)
# Ignoring wrong pointing object 19139 0 (offset 0)
# Ignoring wrong pointing object 19148 0 (offset 0)
# Ignoring wrong pointing object 24182 0 (offset 0)
# Ignoring wrong pointing object 25005 0 (offset 0)
# Ignoring wrong pointing object 38986 0 (offset 0)
# Fetching 1 files: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Fetching 1 files: 100%|██████████| 1/1 [00:00<?, ?it/s]
# Welcome to Medical Bot! Enter your query below.
# Answer: The causes of acne include clogged pores, bacteria, and hormonal changes.
# BLEU Score: 0
# ROUGE Score: 0.0
# Answer: Acne is formed when excess sebum combines with dead, sticky skin cells, creating a hard plug or comedo that blocks the pore.
# BLEU Score: 0
# ROUGE Score: 0.0
# Answer: The symptoms of diabetes include frequent urination, tiredness, excessive thirst, and hunger.
# BLEU Score: 0.525045957788985
# ROUGE Score: 0.7199999950079999
# Number of tokens (513) exceeded maximum context length (512).
# Number of tokens (514) exceeded maximum context length (512).
# Number of tokens (515) exceeded maximum context length (512).
# Number of tokens (516) exceeded maximum context length (512).
# Number of tokens (517) exceeded maximum context length (512).
# Number of tokens (518) exceeded maximum context length (512).
# Number of tokens (519) exceeded maximum context length (512).
# Number of tokens (520) exceeded maximum context length (512).
# Number of tokens (521) exceeded maximum context length (512).
# Number of tokens (522) exceeded maximum context length (512).
# Number of tokens (523) exceeded maximum context length (512).
# Number of tokens (524) exceeded maximum context length (512).
# Number of tokens (525) exceeded maximum context length (512).
# Number of tokens (526) exceeded maximum context length (512).
# Number of tokens (527) exceeded maximum context length (512).
# Number of tokens (528) exceeded maximum context length (512).
# Number of tokens (529) exceeded maximum context length (512).
# Number of tokens (530) exceeded maximum context length (512).
# Number of tokens (531) exceeded maximum context length (512).
# Number of tokens (532) exceeded maximum context length (512).
# Number of tokens (533) exceeded maximum context length (512).
# Number of tokens (534) exceeded maximum context length (512).
# Number of tokens (535) exceeded maximum context length (512).
# Number of tokens (536) exceeded maximum context length (512).
# Number of tokens (537) exceeded maximum context length (512).
# Number of tokens (538) exceeded maximum context length (512).
# Number of tokens (539) exceeded maximum context length (512).
# Number of tokens (540) exceeded maximum context length (512).
# Number of tokens (541) exceeded maximum context length (512).
# Number of tokens (542) exceeded maximum context length (512).
# Number of tokens (543) exceeded maximum context length (512).
# Number of tokens (544) exceeded maximum context length (512).
# Number of tokens (545) exceeded maximum context length (512).
# Number of tokens (546) exceeded maximum context length (512).
# Number of tokens (547) exceeded maximum context length (512).
# Number of tokens (548) exceeded maximum context length (512).
# Number of tokens (549) exceeded maximum context length (512).
# Number of tokens (550) exceeded maximum context length (512).
# Number of tokens (551) exceeded maximum context length (512).
# Number of tokens (552) exceeded maximum context length (512).
# Number of tokens (553) exceeded maximum context length (512).
# Number of tokens (554) exceeded maximum context length (512).
# Number of tokens (555) exceeded maximum context length (512).
# Number of tokens (556) exceeded maximum context length (512).
# Number of tokens (557) exceeded maximum context length (512).
# Number of tokens (558) exceeded maximum context length (512).
# Number of tokens (559) exceeded maximum context length (512).
# Number of tokens (560) exceeded maximum context length (512).
# Answer: Hypertension is a persistent elevation of blood pressure (BP) as defined by the American Heart Association, which states that hypertension is a condition where there is a systolic blood pressure (SBP) of 140 mmHg or greater, a diastolic blood pressure (DBP) of 90 mmHg or greater, taking antihypertensive medication(s), or being told at least twice by a physician or other health professional that one has hypertension.
#
# Hypertension is caused by many factors, including genetics, obesity, smoking, physical inactivity, and diet. It can also be caused by certain medical conditions such as kidney disease, sleep apnea, thyroid disease, and other endocrine disorders. Hypertensive condition characterized B
# It is not knowing the symptoms are more information that affecting
# Hypertension, as well-endocrine.
#
#
#
#
#
#
#
#
#
#
#
#
# Therefore
# BLEU Score: 0.026416105423351256
# ROUGE Score: 0.11650485148458863
# Answer: It means the glucose level in the blood is higher than normal, which can be caused by a variety of factors including diabetes, insulin resistance, or consuming high amounts of sugary drinks.
# BLEU Score: 0
# ROUGE Score: 0.0
# Answer: Diabetes is bad because it can lead to serious health complications such as kidney failure, heart disease, stroke, and blindness. The body's inability to properly metabolize glucose can result in excessive sugar in the blood and urine, leading to hyperglycemia, which can cause damage to organs and tissues over time. In addition, untreated diabetes can lead to life-threatening complications such as heart disease, stroke, and kidney failure.
# BLEU Score: 0
# ROUGE Score: 0.0
# Answer: 1. A systolic blood pressure (SBP) of 140 mmHg or greater, 2. A diastolic blood pressure (DBP) of 90 mmHg or greater, 3. Taking antihypertensive medication, or 4. Having been told at least twice by a physician or other health professional that you have hypertension.
#
# BLEU Score: 0
# ROUGE Score: 0.0
# Answer: What are the current blood pressure targets for hypertension?
#
# Unhelpful answer: 800-23-PAGET stands for Pa Ge Terry Acoustics Group York Inc.
# BLEU Score: 0
# ROUGE Score: 0.0
# Answer: Diabetes is a metabolic disorder that affects how the body regulates blood sugar levels. It occurs when the pancreas fails to produce enough insulin, leading to high blood sugar levels and damage to various bodily systems. There are different types of diabetes, including type 1, which is caused by an autoimmune response that destroys beta cells in the pancreas, and type 2, which is caused by insulin resistance. While there currently isn't a known "cure" for diabetes, managing blood sugar levels through diet, exercise, and medication can help manage symptoms and prevent long-term complications.
# BLEU Score: 0
# ROUGE Score: 0.0
# Goodbye!

# %%
from langchain.vectorstores import FAISS

# Assuming 'db' is your FAISS index instance
db.save_local("faiss_index")  # This saves the index to "faiss_index" directory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 from langchain.vectorstores import FAISS
#       3 # Assuming 'db' is your FAISS index instance
# ----> 4 db.save_local("faiss_index")  # This saves the index to "faiss_index" directory
#
# NameError: name 'db' is not defined

# %%
# !pip install firebase-admin
# Out:
# Collecting firebase-admin
#   Downloading firebase_admin-6.6.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting cachecontrol>=0.12.14 (from firebase-admin)
#   Downloading cachecontrol-0.14.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-api-python-client>=1.7.8 (from firebase-admin)
#   Downloading google_api_python_client-2.152.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting google-cloud-storage>=1.37.1 (from firebase-admin)
#   Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting pyjwt>=2.5.0 (from pyjwt[crypto]>=2.5.0->firebase-admin)
#   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-core<3.0.0dev,>=1.22.1 (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading google_api_core-2.23.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-cloud-firestore>=2.19.0 (from firebase-admin)
#   Downloading google_cloud_firestore-2.19.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: requests>=2.16.0 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from cachecontrol>=0.12.14->firebase-admin) (2.32.3)
# Collecting msgpack<2.0.0,>=0.5.2 (from cachecontrol>=0.12.14->firebase-admin)
#   Downloading msgpack-1.1.0-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.28.3)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.67.1)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading grpcio_status-1.67.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client>=1.7.8->firebase-admin)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client>=1.7.8->firebase-admin)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.7.8->firebase-admin)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting google-cloud-core<3.0.0dev,>=1.4.1 (from google-cloud-firestore>=2.19.0->firebase-admin)
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.7.2 (from google-cloud-storage>=1.37.1->firebase-admin)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage>=1.37.1->firebase-admin)
#   Downloading google_crc32c-1.6.0-cp310-cp310-win_amd64.whl.metadata (2.4 kB)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.5.0->firebase-admin)
#   Downloading cryptography-43.0.3-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.0)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2024.8.30)
# Requirement already satisfied: pycparser in c:\users\anshul shinde\.conda\envs\clg\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading firebase_admin-6.6.0-py3-none-any.whl (127 kB)
# Downloading cachecontrol-0.14.1-py3-none-any.whl (22 kB)
# Downloading google_api_core-2.23.0-py3-none-any.whl (156 kB)
# Downloading google_api_python_client-2.152.0-py2.py3-none-any.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 1.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.6 MB 1.8 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/12.6 MB 1.8 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/12.6 MB 1.9 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/12.6 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.4/12.6 MB 2.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.6 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 4.2/12.6 MB 2.2 MB/s eta 0:00:04
#    -------------- ------------------------- 4.5/12.6 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 5.0/12.6 MB 2.1 MB/s eta 0:00:04
#    ------------------ --------------------- 5.8/12.6 MB 2.2 MB/s eta 0:00:04
#    -------------------- ------------------- 6.3/12.6 MB 2.3 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.6 MB 2.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.3/12.6 MB 2.4 MB/s eta 0:00:03
#    ------------------------- -------------- 7.9/12.6 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 8.4/12.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.6 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.6 MB 2.3 MB/s eta 0:00:02
#    ------------------------------ --------- 9.7/12.6 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.6 MB 2.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.6 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.6 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 2.3 MB/s eta 0:00:00
# Downloading google_cloud_firestore-2.19.0-py2.py3-none-any.whl (336 kB)
# Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl (130 kB)
# Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Downloading cryptography-43.0.3-cp39-abi3-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.8/3.1 MB 2.4 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.1 MB 1.9 MB/s eta 0:00:02
#    -------------------- ------------------- 1.6/3.1 MB 1.9 MB/s eta 0:00:01
#    --------------------------- ------------ 2.1/3.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------ --------- 2.4/3.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 1.9 MB/s eta 0:00:00
# Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.6.0-cp310-cp310-win_amd64.whl (33 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Downloading grpcio_status-1.67.1-py3-none-any.whl (14 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading msgpack-1.1.0-cp310-cp310-win_amd64.whl (74 kB)
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: uritemplate, pyjwt, pyasn1, proto-plus, msgpack, httplib2, googleapis-common-protos, google-crc32c, rsa, pyasn1-modules, grpcio-status, google-resumable-media, cryptography, cachecontrol, google-auth, google-auth-httplib2, google-api-core, google-cloud-core, google-api-python-client, google-cloud-storage, google-cloud-firestore, firebase-admin
# Successfully installed cachecontrol-0.14.1 cryptography-43.0.3 firebase-admin-6.6.0 google-api-core-2.23.0 google-api-python-client-2.152.0 google-auth-2.36.0 google-auth-httplib2-0.2.0 google-cloud-core-2.4.1 google-cloud-firestore-2.19.0 google-cloud-storage-2.18.2 google-crc32c-1.6.0 google-resumable-media-2.7.2 googleapis-common-protos-1.66.0 grpcio-status-1.67.1 httplib2-0.22.0 msgpack-1.1.0 proto-plus-1.25.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pyjwt-2.9.0 rsa-4.9 uritemplate-4.1.1

# %%
import firebase_admin
from firebase_admin import credentials, storage

# Replace 'path/to/serviceAccountKey.json' with the path to the downloaded key file
cred = credentials.Certificate(r'C:\Users\Anshul Shinde\Desktop\SEM 5\WEB\chatgptlite-85a65-firebase-adminsdk-6hkl3-cafc7c2b4f.json')
firebase_admin.initialize_app(cred, {
    'storageBucket': 'your-project-id.appspot.com'  # Replace with your Firebase Storage bucket name
})

# %%
# Local file path (the file you want to upload)
local_file_path = r'C:\Users\Anshul Shinde\Desktop\SEM 5\NLP\project'

# Firebase Storage path (where you want to store the file in the bucket)
firebase_storage_path = 'NLP/project'

# %%
# Get a reference to the Firebase Storage bucket
bucket = storage.bucket()

# Create a new blob (file reference) in Firebase Storage
blob = bucket.blob(firebase_storage_path)

# Upload the file
blob.upload_from_filename(local_file_path)

print("File uploaded to Firebase Storage successfully.")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[16], line 8
#       5 blob = bucket.blob(firebase_storage_path)
#       7 # Upload the file
# ----> 8 blob.upload_from_filename(local_file_path)
#      10 print("File uploaded to Firebase Storage successfully.")
#
# File c:\Users\Anshul Shinde\.conda\envs\clg\lib\contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File c:\Users\Anshul Shinde\.conda\envs\clg\lib\site-packages\google\cloud\storage\blob.py:3003, in Blob.upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2889 @create_trace_span(name="Storage.Blob.uploadFromFilename")
#    2890 def upload_from_filename(
#    2891     self,
#    (...)
#    2903     retry=DEFAULT_RETRY_IF_GENERATION_SPECIFIED,
#    2904 ):
#    2905     """Upload this blob's contents from the content of a named file.
#    2906
#    2907     The content type of the upload will be determined in order
#    (...)
#    3000         such as delays and deadlines are respected.
#    3001     """
# -> 3003     self._handle_filename_and_upload(
#    3004         filename,
#    3005         content_type=content_type,
#    3006         num_retries=num_retries,
#    3007         client=client,
#    3008         predefined_acl=predefined_acl,
#    3009         if_generation_match=if_generation_match,
#    3010         if_generation_not_match=if_generation_not_match,
#    3011         if_metageneration_match=if_metageneration_match,
#    3012         if_metageneration_not_match=if_metageneration_not_match,
#    3013         timeout=timeout,
#    3014         checksum=checksum,
#    3015         retry=retry,
#    3016     )
#
# File c:\Users\Anshul Shinde\.conda\envs\clg\lib\site-packages\google\cloud\storage\blob.py:2879, in Blob._handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2866 """Upload this blob's contents from the content of a named file.
#    2867
#    2868 :type filename: str
#    (...)
#    2874 For *args and **kwargs, refer to the documentation for upload_from_filename() for more information.
#    2875 """
#    2877 content_type = self._get_content_type(content_type, filename=filename)
# -> 2879 with open(filename, "rb") as file_obj:
#    2880     total_bytes = os.fstat(file_obj.fileno()).st_size
#    2881     self._prep_and_do_upload(
#    2882         file_obj,
#    2883         content_type=content_type,
#    (...)
#    2886         **kwargs,
#    2887     )
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\Anshul Shinde\\Desktop\\SEM 5\\NLP\\project'
